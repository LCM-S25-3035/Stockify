# %%
# ppo_minimal_fixed.py
"""
Fixed PPO example for CartPole using Gymnasium (new API)
"""

import gymnasium as gym
from stable_baselines3 import PPO

# 1️⃣ Create the environment
env = gym.make("CartPole-v1")   # Gymnasium version

# 2️⃣ Initialize PPO model
model = PPO(
    policy="MlpPolicy",
    env=env,
    verbose=1,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01
)

# 3️⃣ Train the model
print("🚀 Training PPO agent...")
model.learn(total_timesteps=50_000)  # lower steps for quick test
print("✅ Training finished.")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 🚀 Training PPO agent...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | 24       |
# | time/              |          |
# |    fps             | 1722     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.5        |
# |    ep_rew_mean          | 25.5        |
# | time/                   |             |
# |    fps                  | 1229        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009212196 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.0151     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.12        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 55.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.1        |
# |    ep_rew_mean          | 33.1        |
# | time/                   |             |
# |    fps                  | 1145        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011908622 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0812      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 32.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.5        |
# |    ep_rew_mean          | 46.5        |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012144606 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 49.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.3        |
# |    ep_rew_mean          | 62.3        |
# | time/                   |             |
# |    fps                  | 1054        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007436273 |
# |    clip_fraction        | 0.0498      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 64.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78           |
# |    ep_rew_mean          | 78           |
# | time/                   |              |
# |    fps                  | 1022         |
# |    iterations           | 6            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0073046433 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | 0.392        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.4         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0156      |
# |    value_loss           | 68.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.5        |
# |    ep_rew_mean          | 93.5        |
# | time/                   |             |
# |    fps                  | 1015        |
# |    iterations           | 7           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011518682 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00983    |
# |    value_loss           | 43.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 8           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003674409 |
# |    clip_fraction        | 0.0198      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.35        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 41.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 126        |
# |    ep_rew_mean          | 126        |
# | time/                   |            |
# |    fps                  | 1006       |
# |    iterations           | 9          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00482602 |
# |    clip_fraction        | 0.0366     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.585     |
# |    explained_variance   | 0.793      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.9       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00561   |
# |    value_loss           | 29.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 1001         |
# |    iterations           | 10           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0064177616 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.572       |
# |    explained_variance   | 0.712        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.69         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00552     |
# |    value_loss           | 42.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 977          |
# |    iterations           | 11           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0062752953 |
# |    clip_fraction        | 0.0614       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.754        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.56         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.01        |
# |    value_loss           | 29.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 185          |
# |    ep_rew_mean          | 185          |
# | time/                   |              |
# |    fps                  | 981          |
# |    iterations           | 12           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0025432003 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | 0.73         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.8         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00472     |
# |    value_loss           | 40.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 985          |
# |    iterations           | 13           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0050446773 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | 0.479        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.96         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00701     |
# |    value_loss           | 16.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 221         |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 988         |
# |    iterations           | 14          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018795159 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.538      |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.99        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 9.63        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 237          |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 984          |
# |    iterations           | 15           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0039008036 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | 0.0296       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.23         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000321    |
# |    value_loss           | 24.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 253          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 970          |
# |    iterations           | 16           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0068948814 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.52        |
# |    explained_variance   | 0.725        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.326        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 13.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 271          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 972          |
# |    iterations           | 17           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0060121687 |
# |    clip_fraction        | 0.0792       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | 0.711        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0794       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0068      |
# |    value_loss           | 0.692        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | 286         |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 18          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.002730988 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | -0.00128    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00944     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 0.502       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | 302         |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 19          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006258161 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | -0.0574     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0328      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 0.306       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 317          |
# |    ep_rew_mean          | 317          |
# | time/                   |              |
# |    fps                  | 974          |
# |    iterations           | 20           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0050572315 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.0372       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0232       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 0.204        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 336          |
# |    ep_rew_mean          | 336          |
# | time/                   |              |
# |    fps                  | 970          |
# |    iterations           | 21           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0017051335 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.542       |
# |    explained_variance   | -0.00606     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0195       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000439    |
# |    value_loss           | 0.122        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 354         |
# |    ep_rew_mean          | 354         |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 22          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004416624 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | -0.0321     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0185      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00204    |
# |    value_loss           | 0.09        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 370          |
# |    ep_rew_mean          | 370          |
# | time/                   |              |
# |    fps                  | 963          |
# |    iterations           | 23           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0026018014 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.515       |
# |    explained_variance   | 0.0422       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -5.94e-05    |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000852    |
# |    value_loss           | 0.0507       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | 383         |
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 24          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004365988 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00537    |
# |    value_loss           | 0.0326      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 397          |
# |    ep_rew_mean          | 397          |
# | time/                   |              |
# |    fps                  | 965          |
# |    iterations           | 25           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0040099076 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.517       |
# |    explained_variance   | 0.417        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00238     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 0.0231       |
# ------------------------------------------
# ✅ Training finished.

# %%
# 4️⃣ Save the model
model.save("ppo_cartpole_model_fixed")
print("📁 Model saved as ppo_cartpole_model_fixed.zip")

# 5️⃣ Test the trained agent
obs, _ = env.reset()   # ✅ Gymnasium reset returns (obs, info)
for step in range(10):
    action, _states = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)  # ✅ New step API returns 5 values
    done = terminated or truncated

    env.render()  # Show simulation

    if done:
        obs, _ = env.reset()

env.close()
# Out:
# 📁 Model saved as ppo_cartpole_model_fixed.zip
